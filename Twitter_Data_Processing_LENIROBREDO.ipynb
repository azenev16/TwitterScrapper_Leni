# %% [markdown]
# <a href="https://colab.research.google.com/github/azenev16/TwitterScrapper_Leni/blob/main/Twitter_Data_Processing_LENIROBREDO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import nltk
from nltk.corpus import stopwords
from nltk.corpus import words
from nltk.tokenize import word_tokenize
from collections import Counter
import re
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('words')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %%
text = open('extracted-tweets.txt', "r",encoding="ISO-8859-1")
data = text.read()
print(data)
# Out:
# '@sejoalzir @lenirobredo ð'
# 'Importante na kilala natin ang ating kanditato na sinusuportahan, di ba mga #kakampink?\n\nAlamin natin kung ano nga ba ang mga paninindigan ni Leni Robredo pagdating sa mga kritikal na isyu ng Pilipinas.\n\n#LabanLeni2022\n#LeniKiko2022 \n(Repost from @teamlenirobredo) https://t.co/laAl9Cv7HN'
# '@News5PH Marcos is a representation of abusive and corrupt governance and thats what VP Leni is after for..not a fight between families or parties..ikaw ang mababaw.'
# 'Pero gusto mo gumagawa ng away? Lols. Tingin sa salamin, Isko.\n\nHindi ganon kababaw si VP @lenirobredo. Pakisilip na lang po ang mga nagawa nya sa pandemya at sa bayan. https://t.co/pZVFfsGSZ5'
# '@SyLicoNgaAko @IskoMoreno @lenirobredo susko! nakakastress syang panoorin, antaas ng ere at dinadaan sa boladas ang mga pananalita ð'
# '@sejoalzir @lenirobredo mam VP ð'
# '@k0opik0o @TheDoctorLuck @lenirobredo Root cause?ððð'
# ...

# %%
ensw = stopwords.words('english')

# %%
print(ensw)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than',
# ...

# %%
textArray = word_tokenize(data.lower())

# %%
filterArray = [item for item in textArray if item not in ensw]

# %%
print(filterArray)
# Out:
# ["'", '@', 'sejoalzir', '@', 'lenirobredo', "ð\x9f\x98\x8a'", "'importante", 'na', 'kilala', 'natin', 'ang', 'ating', 'kanditato', 'na', 'sinusuportahan', ',', 'di', 'ba', 'mga', '#', 'kakampink', '?', '\\n\\nalamin', 'natin', 'kung', 'ano', 'nga', 'ba', 'ang', 'mga', 'paninindigan', 'ni', 'leni', 'robredo', 'pagdating', 'sa', 'mga', 'kritikal', 'na', 'isyu', 'ng', 'pilipinas.\\n\\n', '#', 'labanleni2022\\n', '#', 'lenikiko2022', '\\n', '(', 'repost', '@', 'teamlenirobredo', ')', 'https', ':', "//t.co/laal9cv7hn'", "'", '@', 'news5ph', 'marcos', 'representation', 'abusive', 'corrupt', 'governance', 'thats', 'vp', 'leni', 'for..not', 'fight', 'families', 'parties..ikaw', 'ang', 'mababaw', '.', "'", "'pero", 'gusto', 'mo', 'gumagawa', 'ng', 'away', '?', 'lols', '.', 'tingin', 'sa', 'salamin', ',', 'isko.\\n\\nhindi', 'ganon', 'kababaw', 'si', 'vp', '@', 'lenirobredo', '.', 'pakisilip', 'na', 'lang', 'po', 'ang', 'mga', 'nagawa', 'nya', 'sa', 'pandemya', 'sa', 'bayan', '.', 'https', ':'
# ...

# %%
stringFilter = ','.join(filterArray)

# %%
print(stringFilter)
# Out:
# ',@,sejoalzir,@,lenirobredo,ð','importante,na,kilala,natin,ang,ating,kanditato,na,sinusuportahan,,,di,ba,mga,#,kakampink,?,\n\nalamin,natin,kung,ano,nga,ba,ang,mga,paninindigan,ni,leni,robredo,pagdating,sa,mga,kritikal,na,isyu,ng,pilipinas.\n\n,#,labanleni2022\n,#,lenikiko2022,\n,(,repost,@,teamlenirobredo,),https,:,//t.co/laal9cv7hn',',@,news5ph,marcos,representation,abusive,corrupt,governance,thats,vp,leni,for..not,fight,families,parties..ikaw,ang,mababaw,.,','pero,gusto,mo,gumagawa,ng,away,?,lols,.,tingin,sa,salamin,,,isko.\n\nhindi,ganon,kababaw,si,vp,@,lenirobredo,.,pakisilip,na,lang,po,ang,mga,nagawa,nya,sa,pandemya,sa,bayan,.,https,:,//t.co/pzvffsgsz5',',@,sylicongaako,@,iskomoreno,@,lenirobredo,susko,!,nakakastress,syang,panoorin,,,antaas,ng,ere,dinadaan,sa,boladas,ang,mga,pananalita,ð',',@,sejoalzir,@,lenirobredo,mam,vp,ð',',@,k0opik0o,@,thedoctorluck,@,lenirobredo,root,cause,?,ððð',',@,eatbulaga,@,allanklownz,@,mainedcm,@,pauleenl_sotto,@,vicegandako,@,bam
# ...

# %%
words = set(nltk.corpus.words.words()[:100])
print(words)
# Out:
# {'abatised', 'abandoner', 'Abadite', 'abater', 'abashed', 'abandonee', 'abaissed', 'abactinal', 'Aaron', 'Aani', 'aalii', 'abarticulation', 'abask', 'abaction', 'Abarambo', 'abave', 'Aaronical', 'abashless', 'abb', 'abatis', 'abactinally', 'abasedness', 'abasic', 'abaiser', 'abaff', 'abaisance', 'abandonedly', 'abacay', 'aa', 'abbacomes', 'abaculus', 'abandonment', 'A', 'abattoir', 'abandoned', 'aback', 'aardwolf', 'Aaru', 'abatement', 'abandonable', 'abaciscus', 'abasia', 'abasedly', 'abasement', 'abalienate', 'abator', 'Abama', 'abampere', 'Ababdeh', 'abaser', 'abased', 'abactor', 'abaft', 'abashedly', 'abacus', 'abase', 'aardvark', 'abacist', 'abandon', 'aam', 'abacate', 'abaca', 'abatable', 'Abaris', 'abac', 'Abanic', 'abalone', 'abastardize', 'abacinate', 'abbacy', 'Abatua', 'Abbadide', 'abaze', 'Ab', 'Abassin', 'Aaronitic', 'abaxial', 'abate', 'abarthrosis', 'a', 'abalienation', 'Aaronic', 'abas', 'abashlessly', 'abature', 'abashedness', 'Abasgi', 'abashment', 'abaxile', 'Abba'
# ...

# %%
stringString = re.sub('\W+','\n',stringFilter)

f = open ('newList.txt', 'w',errors="ignore")
f.write(stringString)
f.close()

# %%
#@title Default title text
with open ('newList.txt') as fp:
    line = fp.readline()
    cnt = 1
    
    f = open('finalList.txt', 'w',errors="ignore")
    while line:
        data = line.strip()
        if data not in words:
            print(data)
            f.write(data + "\n")
        line = fp.readline()
        cnt += 1
# Out:
# Streaming output truncated to the last 5000 lines.
# si
# leody
# kung
# di
# nila
# kilala
# feeling
# nila
# nuisance
# candidate
# lang
# kaya
# ganun
# magreact
# kung
# may
# idea
# man
# sila
# kubg
# sino
# siya
# think
# another
# reason
# konti
# ng
# support
# base
# niya
# compared
# kay
# vp
# leni
# tapos
# nagpoppwer
# play
# siya
# smth
# he
# may
# vp
# leniâ
# s
# senatorial
# line
# up
# yet
# views
# align
# goal
# still
# comforting
# go
# neri
# ð
# https
# t
# co
# 2zs0apvil6
# liz_culas18
# manilabulletin
# hindi
# ako
# maka
# marcos
# jr
# pero
# would
# reply
# claim
# leni
# robredo
# heart
# reactors
# s
# names
# middle
# east
# sa
# rappler
# survey
# dickgordondg
# lenirobredo
# vp
# trusts
# hope
# vote
# n
# t
# need
# balimbing
# leaders
# trying
# times
# iammarsapuez7
# daniasrop
# dennismmasirag
# jonathanandal_
# jennylynnation
# gmanews
# hmm
# ano
# po
# kinalaman
# ni
# vp
# leni
# sa
# sinasabi
# mong
# dilawan
# na
# projects
# na
# siya
# ...

# %%
finalText = open('finalList.txt', "r")
finalData = finalText.read()

tokenwords = word_tokenize(finalData)
countWords = Counter(tokenwords)

# %%
print(countWords)
# Out:
# Counter({'leni': 276, 'lenirobredo': 264, 'ð': 261, 'sa': 232, 'vp': 206, 'na': 202, 'ang': 179, 'n': 174, 'ng': 160, 't': 137, 'co': 123, 'mga': 118, 'https': 104, 'si': 95, 'lang': 76, 'ni': 73, 'po': 71, 'robredo': 67, 'pa': 56, 'hindi': 48, 'ba': 44, 'mo': 44, 's': 44, 'may': 42, 'kay': 41, 'di': 38, 'para': 37, 'â': 37, 'nyo': 36, 'yung': 36, 'iskomoreno': 35, 'kayo': 35, 'ka': 35, 'naman': 33, 'ako': 31, 'ko': 30, 'nga': 29, 'kaya': 29, 'yan': 28, 'marcos': 27, 'kung': 26, 'president': 25, 'isko': 24, 'nila': 24, 'sila': 24, 'pero': 23, 'sylicongaako': 22, 'dickgordondg': 21, 'nya': 20, 'manilabulletin': 20, 'mas': 20, 'ay': 20, 'eh': 20, 'ano': 19, 'pag': 19, 'bbm': 19, 'doc4dead': 19, 'sya': 19, 'siya': 19, 'din': 18, 'walang': 18, 'kasi': 18, 'amp': 18, 'lenikiko2022': 17, 'niya': 17, 'survey': 17, 'nhttps': 17, 'kahit': 17, 'dapat': 16, 'support': 16, 'mag': 15, 'ï': 15, 'mgagwapoforleni': 14, 'said': 14, 'vote': 14, 'natin': 13, 'good': 13, 'talaga': 13, 'kami': 13, 'go': 
# ...

# %%
countList = list(Counter((countWords)).items())
newList = '\n'.join([str(i) for i in countList])

# %%
print(newList)
# Out:
# ('sejoalzir', 3)
# ('lenirobredo', 264)
# ('ð', 261)
# ('importante', 4)
# ('na', 202)
# ('kilala', 3)
# ('natin', 13)
# ('ang', 179)
# ('ating', 3)
# ('kanditato', 1)
# ('sinusuportahan', 1)
# ('di', 38)
# ('ba', 44)
# ('mga', 118)
# ('kakampink', 8)
# ('n', 174)
# ('nalamin', 1)
# ('kung', 26)
# ('ano', 19)
# ('nga', 29)
# ('paninindigan', 5)
# ('ni', 73)
# ('leni', 276)
# ('robredo', 67)
# ('pagdating', 1)
# ('sa', 232)
# ('kritikal', 1)
# ('isyu', 1)
# ('ng', 160)
# ('pilipinas', 6)
# ('labanleni2022', 11)
# ('lenikiko2022', 17)
# ('repost', 1)
# ('teamlenirobredo', 8)
# ('https', 104)
# ('t', 137)
# ('co', 123)
# ('laal9cv7hn', 1)
# ('news5ph', 9)
# ('marcos', 27)
# ('representation', 1)
# ('abusive', 1)
# ('corrupt', 6)
# ('governance', 1)
# ('thats', 1)
# ('vp', 206)
# ('for', 3)
# ('not', 1)
# ('fight', 2)
# ('families', 2)
# ('parties', 1)
# ('ikaw', 10)
# ('mababaw', 2)
# ('pero', 23)
# ('gusto', 10)
# ('mo', 44)
# ('gumagawa', 1)
# ('away', 3)
# ('lols', 1)
# ...

# %%
finalTweets = re.sub("[)!@''$(.#]","", newList)
f = open ('TweetsFrequency.csv', "w")
f.write(finalTweets)
f.close()
